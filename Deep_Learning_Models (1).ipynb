# %%
import os
import pandas as pd
import numpy as np

##tensorflow modules
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Embedding, Dense, SimpleRNN, LSTM, Dropout, BatchNormalization
from tensorflow.keras.layers import Bidirectional,LayerNormalization

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint


## text preprocessing modules
from gensim.parsing.preprocessing import remove_stopwords
from gensim.models import Word2Vec
import re
import nltk
nltk.download('punkt')
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score,auc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, BatchNormalization, Dropout, Embedding, LayerNormalization, Bidirectional
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('Sentiment_news_dataframe.csv')
df.head()
# Out:
#        Date                                              Title  \
# 0  03/10/17        Amber Enterprises files for Rs555 crore IPO
# 1  21/04/18  No need to divorce this stock ; brokerage sees...
# 2  11/07/18  An evening walk down Dalal Street : Trade war ...
# 3  09/01/20  Commodity outlook : Refined soya oil jumps 8 %...
# 4  19/04/17  Nikkei : Tokyo stocks open lower after British...
#
#                                                  URL sentiment  confidence  \
# 0  http://www.livemint.com/Money/DJCTYXYzpDnVT1Ki...  NEGATIVE   -0.987213
# 1  https://www.moneycontrol.com/news/business/sto...  POSITIVE    0.946583
# 2  https://www.moneycontrol.com/news/business/mar...  POSITIVE    0.967994
# 3  https://economictimes.indiatimes.com/markets/c...  NEGATIVE   -0.879617
# 4  http://economictimes.indiatimes.com/markets/st...  NEGATIVE   -0.941918
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Dropping Columns not required

# %%
df = df.drop(['Date','URL','confidence','Unnamed: 5'], axis=1)
df.head()
# Out:
#                                                Title sentiment
# 0        Amber Enterprises files for Rs555 crore IPO  NEGATIVE
# 1  No need to divorce this stock ; brokerage sees...  POSITIVE
# 2  An evening walk down Dalal Street : Trade war ...  POSITIVE
# 3  Commodity outlook : Refined soya oil jumps 8 %...  NEGATIVE
# 4  Nikkei : Tokyo stocks open lower after British...  NEGATIVE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      60000 non-null  object
#  1   sentiment  60000 non-null  object
# dtypes: object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# Check for null values

# %%
df.isnull().sum()
# Out:
# Title        0
# sentiment    0
# dtype: int64

# %% [markdown]
# Drop Duplicates

# %%
df = df.drop_duplicates(subset=["Title"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59973 entries, 0 to 59999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      59973 non-null  object
#  1   sentiment  59973 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
headline= list(df['Title'])
headline[0:2]
# Out:
# ['Amber Enterprises files for Rs555 crore IPO',
#  'No need to divorce this stock ; brokerage sees up to 26 % upside on this wedding portal']

# %%
### Basic text preprocessing where we remove special characters, any tags etc
#### Removal of stopwords
#### Removal of tags
#### Removal of special characters
#### Removal of email id
#### Removal of numbers
text=[]
for r in headline:
  r = re.sub(r'<.*?>',"",r)
  r = re.sub(r'\S+@\S+\s','',r)
  r = re.sub(r'\d+','',r)
  r = re.sub(r'[#$!\*\)\(\\%:;,\'_-]','',r)
  text.append(remove_stopwords(r))

text[0:3]
# Out:
# ['Amber Enterprises files Rs crore IPO',
#  'No need divorce stock brokerage sees upside wedding portal',
#  'An evening walk Dalal Street Trade war fears grips equity markets globe Nifty ends']

# %% [markdown]
# # Tokenisation

# %%
### Now the reviews are faily clean, we will tokenize the reviews and get word embeddings for these
tokenizer=Tokenizer(num_words=15000,lower=True,oov_token='UNK')# out of vocabulory-oov

# %% [markdown]
# Train test split

# %%
## Before applying the tokenizer, lets split the data into train test
train_text=text[:len(text)-6000]
test_text=text[-6000:]
print(len(text),len(train_text),len(test_text))
# Out:
# 59973 53973 6000

# %%
### Now lets tokenize the reviews
tokenizer.fit_on_texts(train_text)

# %%
tokenizer.word_index
# Out:
# {'UNK': 1,
#  'india': 2,
#  'market': 3,
#  'rs': 4,
#  'us': 5,
#  'stocks': 6,
#  'says': 7,
#  'sensex': 8,
#  'nifty': 9,
#  'the': 10,
#  'bank': 11,
#  'growth': 12,
#  'rbi': 13,
#  'china': 14,
#  'economy': 15,
#  'trade': 16,
#  'indian': 17,
#  'live': 18,
#  'new': 19,
#  'budget': 20,
#  'markets': 21,
#  'modi': 22,
#  'global': 23,
#  'news': 24,
#  'crore': 25,
#  'gold': 26,
#  'financial': 27,
#  'oil': 28,
#  'stock': 29,
#  'price': 30,
#  'rupee': 31,
#  'trump': 32,
#  'prices': 33,
#  'economic': 34,
#  'covid': 35,
#  'govt': 36,
#  'buy': 37,
#  'today': 38,
#  'dollar': 39,
#  'q': 40,
#  'sebi': 41,
#  'rate': 42,
#  'year': 43,
#  'share': 44,
#  'express': 45,
#  'coronavirus': 46,
#  'how': 47,
#  'high': 48,
#  'fund': 49,
#  'report': 50,
#  'pm': 51,
#  'business': 52,
#  'policy': 53,
#  'investors': 54,
#  'tax': 55,
#  'government': 56,
#  'day': 57,
#  'shares': 58,
#  'week': 59,
#  'mutual': 60,
#  'street': 61,
#  'world': 62,
#  'funds': 63,
#  'gst': 64,
#  'fy': 65,
#  'time': 66,
#  'likely': 67,
#  'gdp': 68,
#  'investment': 69,
#  'ahead': 70,
#  'higher': 71,
#  'points': 72,
#  'billion': 73,
#  'cut': 74,
#  'why': 75,
#  'years': 76,
#  'ipo': 77,
#  'a': 78,
#  'sector': 79,
#  'में': 80,
#  'data': 81,
#  'rise': 82,
#  'what': 83,
#  'gains': 84,
#  'inflation': 85,
#  'demand': 86,
#  'banks': 87,
#  'hit': 88,
#  'fall': 89,
#  'lakh': 90,
#  'set': 91,
#  'big': 92,
#  'amid': 93,
#  'donald': 94,
#  'record': 95,
#  'focus': 96,
#  'key': 97,
#  'asian': 98,
#  'impact': 99,
#  'ltd': 100,
#  'sell': 101,
#  'rates': 102,
#  'cr': 103,
#  'here': 104,
#  'fed': 105,
#  'sales': 106,
#  'rises': 107,
#  'tata': 108,
#  'low': 109,
#  'rally': 110,
#  'deal': 111,
#  'invest': 112,
#  'capital': 113,
#  'companies': 114,
#  'finance': 115,
#  'bse': 116,
#  'target': 117,
#  'boost': 118,
#  'it': 119,
#  'sbi': 120,
#  'nse': 121,
#  'crude': 122,
#  'lower': 123,
#  'open': 124,
#  'need': 125,
#  'narendra': 126,
#  'end': 127,
#  'money': 128,
#  'million': 129,
#  'earnings': 130,
#  'month': 131,
#  'hits': 132,
#  'profit': 133,
#  'के': 134,
#  'in': 135,
#  'auto': 136,
#  'outlook': 137,
#  'debt': 138,
#  'recovery': 139,
#  'term': 140,
#  'crisis': 141,
#  'fiscal': 142,
#  'asia': 143,
#  'ceo': 144,
#  'good': 145,
#  'industry': 146,
#  'jobs': 147,
#  'tech': 148,
#  's': 149,
#  'bond': 150,
#  'falls': 151,
#  'plans': 152,
#  'war': 153,
#  'd': 154,
#  'equity': 155,
#  'pharma': 156,
#  'post': 157,
#  'real': 158,
#  'launch': 159,
#  'podcast': 160,
#  'cuts': 161,
#  'th': 162,
#  'meet': 163,
#  'paise': 164,
#  'power': 165,
#  'lockdown': 166,
#  'steel': 167,
#  'digital': 168,
#  'help': 169,
#  'long': 170,
#  'plan': 171,
#  'की': 172,
#  'times': 173,
#  'retail': 174,
#  'wall': 175,
#  'experts': 176,
#  'know': 177,
#  'offers': 178,
#  'hdfc': 179,
#  'jaitley': 180,
#  'credit': 181,
#  'm': 182,
#  'support': 183,
#  'strong': 184,
#  'g': 185,
#  'fm': 186,
#  'raise': 187,
#  'demonetisation': 188,
#  'view': 189,
#  'sees': 190,
#  'march': 191,
#  'risk': 192,
#  'firms': 193,
#  'needs': 194,
#  'minister': 195,
#  'services': 196,
#  'election': 197,
#  'foreign': 198,
#  'chief': 199,
#  'gets': 200,
#  'survey': 201,
#  'opens': 202,
#  'check': 203,
#  'arun': 204,
#  'pts': 205,
#  'pandemic': 206,
#  'despite': 207,
#  'exports': 208,
#  'hike': 209,
#  'investments': 210,
#  'yes': 211,
#  'congress': 212,
#  'reliance': 213,
#  'loan': 214,
#  'top': 215,
#  'f': 216,
#  'hold': 217,
#  'president': 218,
#  'o': 219,
#  'trading': 220,
#  'will': 221,
#  'gain': 222,
#  'bjp': 223,
#  'k': 224,
#  'p': 225,
#  'slowdown': 226,
#  'talks': 227,
#  'union': 228,
#  'net': 229,
#  'trillion': 230,
#  'saudi': 231,
#  'months': 232,
#  'small': 233,
#  'united': 234,
#  'launches': 235,
#  'icici': 236,
#  'sitharaman': 237,
#  'soon': 238,
#  'ril': 239,
#  'online': 240,
#  'continue': 241,
#  'delhi': 242,
#  'near': 243,
#  'may': 244,
#  'results': 245,
#  'june': 246,
#  'income': 247,
#  'eyes': 248,
#  'fresh': 249,
#  'to': 250,
#  'chinese': 251,
#  'motors': 252,
#  'bonds': 253,
#  'stimulus': 254,
#  'state': 255,
#  'weak': 256,
#  'factors': 257,
#  'securities': 258,
#  'estate': 259,
#  'april': 260,
#  'after': 261,
#  'start': 262,
#  'return': 263,
#  'hopes': 264,
#  'centre': 265,
#  'future': 266,
#  'best': 267,
#  'cash': 268,
#  'better': 269,
#  'corporate': 270,
#  'imf': 271,
#  'things': 272,
#  'का': 273,
#  'quotes': 274,
#  'expect': 275,
#  'moneycontrol': 276,
#  'से': 277,
#  'tips': 278,
#  'stake': 279,
#  'is': 280,
#  'reforms': 281,
#  'raises': 282,
#  'look': 283,
#  'biggest': 284,
#  'remain': 285,
#  'firm': 286,
#  'japan': 287,
#  'dont': 288,
#  'opinion': 289,
#  'mahindra': 290,
#  'group': 291,
#  'infosys': 292,
#  'singh': 293,
#  'job': 294,
#  'rising': 295,
#  'no': 296,
#  'bids': 297,
#  'ends': 298,
#  'slips': 299,
#  'highs': 300,
#  'pakistan': 301,
#  'industries': 302,
#  'returns': 303,
#  'bell': 304,
#  'flat': 305,
#  'brexit': 306,
#  'revenue': 307,
#  'life': 308,
#  'this': 309,
#  'kotak': 310,
#  'push': 311,
#  'portfolio': 312,
#  'opening': 313,
#  'morning': 314,
#  'etmarkets': 315,
#  'ban': 316,
#  'quarter': 317,
#  'vs': 318,
#  'grow': 319,
#  'positive': 320,
#  'apple': 321,
#  'expected': 322,
#  'second': 323,
#  'housing': 324,
#  'seeks': 325,
#  'korea': 326,
#  'energy': 327,
#  'consumer': 328,
#  'equities': 329,
#  'cues': 330,
#  'for': 331,
#  'sale': 332,
#  'lead': 333,
#  'iran': 334,
#  'surge': 335,
#  'deficit': 336,
#  'mark': 337,
#  'central': 338,
#  'supply': 339,
#  'banking': 340,
#  'jumps': 341,
#  'monetary': 342,
#  'cent': 343,
#  'change': 344,
#  'home': 345,
#  'review': 346,
#  'work': 347,
#  'sectors': 348,
#  'पर': 349,
#  'we': 350,
#  'rahul': 351,
#  'short': 352,
#  'kingdom': 353,
#  'cap': 354,
#  'amazon': 355,
#  'fpis': 356,
#  'gandhi': 357,
#  'private': 358,
#  'wealth': 359,
#  'seen': 360,
#  'stay': 361,
#  'बाजार': 362,
#  'mf': 363,
#  'right': 364,
#  'people': 365,
#  'shah': 366,
#  'investing': 367,
#  'silver': 368,
#  'opec': 369,
#  'tv': 370,
#  'december': 371,
#  'inc': 372,
#  'insurance': 373,
#  'fears': 374,
#  'moody': 375,
#  'early': 376,
#  'as': 377,
#  'july': 378,
#  'company': 379,
#  'like': 380,
#  'issue': 381,
#  'rural': 382,
#  'value': 383,
#  'index': 384,
#  'manufacturing': 385,
#  'tcs': 386,
#  'drive': 387,
#  'north': 388,
#  'way': 389,
#  'air': 390,
#  'bitcoin': 391,
#  'airtel': 392,
#  'investor': 393,
#  'elections': 394,
#  'nirmala': 395,
#  'september': 396,
#  'dalal': 397,
#  'governor': 398,
#  'case': 399,
#  'states': 400,
#  'steady': 401,
#  'offer': 402,
#  'office': 403,
#  'latest': 404,
#  'international': 405,
#  'double': 406,
#  'poll': 407,
#  'maruti': 408,
#  'create': 409,
#  'note': 410,
#  'bad': 411,
#  'projects': 412,
#  'bharat': 413,
#  'bn': 414,
#  'major': 415,
#  'list': 416,
#  'e': 417,
#  'watch': 418,
#  'liquidity': 419,
#  'virus': 420,
#  'south': 421,
#  'with': 422,
#  'food': 423,
#  't': 424,
#  'august': 425,
#  'i': 426,
#  'asset': 427,
#  'issues': 428,
#  'ideas': 429,
#  'forecast': 430,
#  'pay': 431,
#  'days': 432,
#  'emerging': 433,
#  'farmers': 434,
#  'ease': 435,
#  'bajaj': 436,
#  'loans': 437,
#  'far': 438,
#  'worth': 439,
#  'output': 440,
#  'taking': 441,
#  'takes': 442,
#  'cases': 443,
#  'health': 444,
#  'measures': 445,
#  'bullish': 446,
#  'buying': 447,
#  'futures': 448,
#  'drop': 449,
#  'google': 450,
#  'meeting': 451,
#  'है': 452,
#  'chairman': 453,
#  'risks': 454,
#  'idea': 455,
#  'come': 456,
#  'from': 457,
#  'analysts': 458,
#  'led': 459,
#  'kumar': 460,
#  'norms': 461,
#  'electric': 462,
#  'calls': 463,
#  'psu': 464,
#  'farm': 465,
#  'close': 466,
#  'vaccine': 467,
#  'looking': 468,
#  'run': 469,
#  'space': 470,
#  'october': 471,
#  'सेंसेक्स': 472,
#  'concerns': 473,
#  'turn': 474,
#  'jio': 475,
#  'rules': 476,
#  'signs': 477,
#  'maharashtra': 478,
#  'level': 479,
#  'rating': 480,
#  'शेयर': 481,
#  'cost': 482,
#  'losses': 483,
#  'axis': 484,
#  'november': 485,
#  'asks': 486,
#  'looks': 487,
#  'amc': 488,
#  'mumbai': 489,
#  'jet': 490,
#  'yields': 491,
#  'board': 492,
#  'ministry': 493,
#  'mid': 494,
#  'country': 495,
#  'summit': 496,
#  'now': 497,
#  'bets': 498,
#  'realty': 499,
#  'midcap': 500,
#  'niti': 501,
#  'infrastructure': 502,
#  'warns': 503,
#  'l': 504,
#  'domestic': 505,
#  'show': 506,
#  'worst': 507,
#  'jump': 508,
#  'wants': 509,
#  'want': 510,
#  'should': 511,
#  'bet': 512,
#  'increase': 513,
#  'of': 514,
#  'commodity': 515,
#  'usd': 516,
#  'january': 517,
#  'products': 518,
#  'strategy': 519,
#  'shows': 520,
#  'green': 521,
#  'all': 522,
#  'public': 523,
#  'uber': 524,
#  'scheme': 525,
#  'makes': 526,
#  'picks': 527,
#  'biden': 528,
#  'making': 529,
#  'relief': 530,
#  'package': 531,
#  'nearly': 532,
#  'arvind': 533,
#  'loss': 534,
#  'fuel': 535,
#  'st': 536,
#  'women': 537,
#  'national': 538,
#  'use': 539,
#  'tensions': 540,
#  'can': 541,
#  'biz': 542,
#  'dips': 543,
#  'extends': 544,
#  'currency': 545,
#  'traders': 546,
#  'steps': 547,
#  'infra': 548,
#  'midcaps': 549,
#  'ready': 550,
#  'ties': 551,
#  'volatility': 552,
#  'track': 553,
#  'assets': 554,
#  'production': 555,
#  'worries': 556,
#  'these': 557,
#  'drops': 558,
#  'story': 559,
#  'reserve': 560,
#  'cities': 561,
#  'aayog': 562,
#  'coming': 563,
#  'xi': 564,
#  'gainers': 565,
#  'cnbc': 566,
#  'opportunity': 567,
#  'action': 568,
#  'nbfcs': 569,
#  'development': 570,
#  'indians': 571,
#  'pnb': 572,
#  'surges': 573,
#  'free': 574,
#  'deals': 575,
#  'export': 576,
#  'holds': 577,
#  'on': 578,
#  'panel': 579,
#  'cm': 580,
#  'updates': 581,
#  'startups': 582,
#  'play': 583,
#  'working': 584,
#  'climate': 585,
#  'ने': 586,
#  'consumption': 587,
#  'february': 588,
#  'benefit': 589,
#  'mobile': 590,
#  'announces': 591,
#  'pick': 592,
#  'house': 593,
#  'suzuki': 594,
#  'growing': 595,
#  'h': 596,
#  'edge': 597,
#  'facebook': 598,
#  'polls': 599,
#  'expects': 600,
#  'samsung': 601,
#  'face': 602,
#  'funding': 603,
#  'repo': 604,
#  'metal': 605,
#  'un': 606,
#  'base': 607,
#  'eu': 608,
#  'highest': 609,
#  'up': 610,
#  'cement': 611,
#  'airways': 612,
#  'season': 613,
#  'goyal': 614,
#  'petrol': 615,
#  'inflows': 616,
#  'half': 617,
#  'study': 618,
#  'spending': 619,
#  'sanctions': 620,
#  'startup': 621,
#  'monday': 622,
#  'walk': 623,
#  'tariffs': 624,
#  'build': 625,
#  'going': 626,
#  'recession': 627,
#  'sun': 628,
#  'तेजी': 629,
#  'imports': 630,
#  'tops': 631,
#  'woes': 632,
#  'decision': 633,
#  'reasons': 634,
#  'largest': 635,
#  'businesses': 636,
#  'management': 637,
#  'numbers': 638,
#  'bulls': 639,
#  'wont': 640,
#  'fmcg': 641,
#  'को': 642,
#  'pressure': 643,
#  'md': 644,
#  'status': 645,
#  'fight': 646,
#  'gujarat': 647,
#  'ambani': 648,
#  'slip': 649,
#  'potential': 650,
#  'patel': 651,
#  'exit': 652,
#  'official': 653,
#  'road': 654,
#  'healthcare': 655,
#  'bring': 656,
#  'nod': 657,
#  'expectations': 658,
#  'arabia': 659,
#  'technology': 660,
#  'european': 661,
#  'cars': 662,
#  'movers': 663,
#  'head': 664,
#  'revival': 665,
#  'chidambaram': 666,
#  'an': 667,
#  'political': 668,
#  'gas': 669,
#  'security': 670,
#  'ratings': 671,
#  'itc': 672,
#  'remains': 673,
#  'decline': 674,
#  'levels': 675,
#  'non': 676,
#  'win': 677,
#  'evening': 678,
#  'fpi': 679,
#  'media': 680,
#  'order': 681,
#  'monsoon': 682,
#  'till': 683,
#  'eases': 684,
#  'secretary': 685,
#  'hikes': 686,
#  'das': 687,
#  'car': 688,
#  'singapore': 689,
#  'msmes': 690,
#  'uk': 691,
#  'bps': 692,
#  'posts': 693,
#  'special': 694,
#  'pre': 695,
#  'piyush': 696,
#  'commerce': 697,
#  'spot': 698,
#  'bharti': 699,
#  'australia': 700,
#  'court': 701,
#  'goods': 702,
#  'diesel': 703,
#  'u': 704,
#  'sentiment': 705,
#  'away': 706,
#  'step': 707,
#  'challenges': 708,
#  'continues': 709,
#  'telecom': 710,
#  'schemes': 711,
#  'overseas': 712,
#  'details': 713,
#  'factory': 714,
#  'over': 715,
#  'macro': 716,
#  'based': 717,
#  'leaders': 718,
#  'friday': 719,
#  'premium': 720,
#  'closes': 721,
#  'countries': 722,
#  'orders': 723,
#  'slow': 724,
#  'smart': 725,
#  'revive': 726,
#  'education': 727,
#  'activity': 728,
#  'sets': 729,
#  'flipkart': 730,
#  'trades': 731,
#  'lending': 732,
#  'large': 733,
#  'amit': 734,
#  'stop': 735,
#  'improve': 736,
#  'mukesh': 737,
#  'mn': 738,
#  'highlights': 739,
#  'cautious': 740,
#  'subramanian': 741,
#  'slump': 742,
#  'closing': 743,
#  'test': 744,
#  'expansion': 745,
#  'lose': 746,
#  'adani': 747,
#  'reach': 748,
#  'party': 749,
#  'pradesh': 750,
#  'session': 751,
#  'indices': 752,
#  'industrial': 753,
#  'dip': 754,
#  'visit': 755,
#  'trend': 756,
#  'gives': 757,
#  'mpc': 758,
#  'russia': 759,
#  'current': 760,
#  'europe': 761,
#  'bull': 762,
#  'travel': 763,
#  'sabha': 764,
#  'technical': 765,
#  'workers': 766,
#  'payments': 767,
#  'buys': 768,
#  'update': 769,
#  'v': 770,
#  'federal': 771,
#  'add': 772,
#  'more': 773,
#  'karnataka': 774,
#  'wednesday': 775,
#  'role': 776,
#  'series': 777,
#  'not': 778,
#  'social': 779,
#  'smartphone': 780,
#  'coal': 781,
#  'hero': 782,
#  'fdi': 783,
#  'defence': 784,
#  'changed': 785,
#  'local': 786,
#  'hotels': 787,
#  'touch': 788,
#  'project': 789,
#  'urjit': 790,
#  'point': 791,
#  'urges': 792,
#  'quality': 793,
#  'extend': 794,
#  'council': 795,
#  'motilal': 796,
#  'oswal': 797,
#  'moves': 798,
#  'seek': 799,
#  'duty': 800,
#  'dr': 801,
#  'range': 802,
#  'avoid': 803,
#  'mixed': 804,
#  'शेयरों': 805,
#  'options': 806,
#  'faces': 807,
#  'unlikely': 808,
#  'one': 809,
#  'rajan': 810,
#  'festive': 811,
#  'forms': 812,
#  'correction': 813,
#  'metals': 814,
#  'aims': 815,
#  'और': 816,
#  'kashmir': 817,
#  'agriculture': 818,
#  'negative': 819,
#  'policies': 820,
#  'visa': 821,
#  'reform': 822,
#  'challenge': 823,
#  'tells': 824,
#  'हैं': 825,
#  'address': 826,
#  'बैंक': 827,
#  'b': 828,
#  'bengaluru': 829,
#  'jinping': 830,
#  'thursday': 831,
#  'euro': 832,
#  'brand': 833,
#  'et': 834,
#  'shaktikanta': 835,
#  'listing': 836,
#  'tomorrow': 837,
#  'gadkari': 838,
#  'service': 839,
#  'city': 840,
#  'possible': 841,
#  'at': 842,
#  'volatile': 843,
#  'kong': 844,
#  'edelweiss': 845,
#  'effect': 846,
#  'easing': 847,
#  'speech': 848,
#  'plant': 849,
#  'card': 850,
#  'costs': 851,
#  'turns': 852,
#  'are': 853,
#  'opportunities': 854,
#  'cards': 855,
#  'hong': 856,
#  'टुडे': 857,
#  'अंक': 858,
#  'merger': 859,
#  'क्या': 860,
#  'pmi': 861,
#  'iphone': 862,
#  'book': 863,
#  'import': 864,
#  'selling': 865,
#  'xiaomi': 866,
#  'nitin': 867,
#  'रेट': 868,
#  'straight': 869,
#  'reddy': 870,
#  'forex': 871,
#  'reports': 872,
#  'act': 873,
#  'morgan': 874,
#  'edges': 875,
#  'r': 876,
#  'momentum': 877,
#  'keeps': 878,
#  'needed': 879,
#  'rallies': 880,
#  'launched': 881,
#  'vodafone': 882,
#  'great': 883,
#  'motor': 884,
#  'farmer': 885,
#  'dow': 886,
#  'hope': 887,
#  'class': 888,
#  'exchange': 889,
#  'solar': 890,
#  'account': 891,
#  'eye': 892,
#  'ecb': 893,
#  'savings': 894,
#  'reduce': 895,
#  'wipro': 896,
#  'rebound': 897,
#  'land': 898,
#  'bigger': 899,
#  'indigo': 900,
#  'getting': 901,
#  'america': 902,
#  'lok': 903,
#  'signals': 904,
#  'platform': 905,
#  'sharma': 906,
#  'targets': 907,
#  'crash': 908,
#  'falling': 909,
#  'changes': 910,
#  'operations': 911,
#  'diwali': 912,
#  'units': 913,
#  'your': 914,
#  'threat': 915,
#  'white': 916,
#  'segment': 917,
#  'middle': 918,
#  'raghuram': 919,
#  'worry': 920,
#  'daily': 921,
#  'hyundai': 922,
#  'if': 923,
#  'general': 924,
#  'joe': 925,
#  'expand': 926,
#  'commodities': 927,
#  'il': 928,
#  'सोने': 929,
#  'property': 930,
#  'hul': 931,
#  'pro': 932,
#  'cos': 933,
#  'confidence': 934,
#  'निफ्टी': 935,
#  'benefits': 936,
#  'phone': 937,
#  'nbfc': 938,
#  'oyo': 939,
#  'estimates': 940,
#  'commercial': 941,
#  'goldman': 942,
#  'रुपये': 943,
#  'tariff': 944,
#  'important': 945,
#  'slows': 946,
#  'kerala': 947,
#  'fitch': 948,
#  'grows': 949,
#  'sip': 950,
#  'yuan': 951,
#  'crucial': 952,
#  'single': 953,
#  'weekly': 954,
#  'goes': 955,
#  'make': 956,
#  'sinha': 957,
#  'row': 958,
#  'brokerages': 959,
#  'fine': 960,
#  'direct': 961,
#  'softbank': 962,
#  'wave': 963,
#  'galaxy': 964,
#  'decade': 965,
#  'x': 966,
#  'law': 967,
#  'planning': 968,
#  'uncertainty': 969,
#  'tough': 970,
#  'lic': 971,
#  'rich': 972,
#  'fastest': 973,
#  'shankar': 974,
#  'ipos': 975,
#  'safe': 976,
#  'save': 977,
#  'vedanta': 978,
#  'plunges': 979,
#  'buyers': 980,
#  'vehicles': 981,
#  'globally': 982,
#  'leads': 983,
#  'politics': 984,
#  'lows': 985,
#  'leader': 986,
#  'mfs': 987,
#  'files': 988,
#  'driving': 989,
#  'poor': 990,
#  'optimism': 991,
#  'minutes': 992,
#  'stanley': 993,
#  'ashok': 994,
#  'buffett': 995,
#  'american': 996,
#  'black': 997,
#  'sources': 998,
#  'east': 999,
#  'cheer': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 26758

# %% [markdown]
# # Glove Embeddings

# %%
embeddings_index= dict()
glove= open('glove.6B.100d.txt','r',encoding='utf-8') 
for line in glove:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs

glove.close()

# %%
len(embeddings_index)
# Out:
# 400000

# %%
### Create an embedding matrix for the vocabulary   
vocab= len(tokenizer.word_index)+1   #determines the length of the vocabulary by adding one to the maximum index of the tokenizer's word index
embedding_matrix = np.zeros((vocab, 100)) #initializes an embedding matrix where vocab is the length of the vocabulary and 100 is the dimensionality of the pre-trained word embeddings 
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector 
        #iterates over each word in the tokenizer's word index and retrieves the pre-trained embedding vector 
        #for that word from a pre-trained embedding index (GloVe). If the embedding vector is found, it is assigned to the corresponding row in the 
        #embedding matrix (i.e., the ith row, where i is the index of the word in the tokenizer's word index). 
        #If the embedding vector is not found, the corresponding row in the embedding matrix is left as a row of zeros.

# %%
embedding_matrix.shape
# Out:
# (26759, 100)

# %%
train_indices=tokenizer.texts_to_sequences(train_text) #using a tokenizer to convert a list of text strings into a list of sequences of integers.

# %%
train_indices[0:5]
# Out:
# [[4649, 1317, 988, 4, 25, 77],
#  [296, 125, 7090, 29, 4650, 190, 1061, 4035, 3714],
#  [667, 678, 623, 397, 61, 16, 153, 374, 6491, 155, 21, 3715, 9, 298],
#  [515, 137, 8824, 7833, 28, 341, 16, 38],
#  [1537, 4232, 6, 124, 123, 1563, 2672, 197, 24]]

# %% [markdown]
# # Pad Sequences

# %% [markdown]
# max_length=64
# The pad_sequences() function takes a list of sequences (in this case, train_indices) as input and pads or truncates the sequences to a fixed length. In this case, the maxlen parameter is set to 64, which means that all sequences will be padded or truncated to a length of 64.
#
# If a sequence is shorter than 64 elements, it will be padded with zeros at the end (since padding='post'). If a sequence is longer than 64 elements, it will be truncated to the first 64 elements.
#
# After the padding is applied, the resulting sequences are stored back into the train_indices variable.
#
# The reason for doing this padding is that neural networks usually require inputs to have a fixed size. In this case, all input sequences are of the same length (64), which makes it possible to use them as input to a neural network model.
#
# Without the padding, the sequences might have different lengths, which would make it difficult to use them as input features for a neural network.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_length=64
train_indices=pad_sequences(train_indices,maxlen=max_length,padding='post')

# %%
df['sentiment'].value_counts()
# Out:
# NEGATIVE    29988
# POSITIVE    29985
# Name: sentiment, dtype: int64

# %%
#replace() method is used to replace the string values "POSITIVE" and "NEGATIVE" in the sentiment column with the integer 
#values 1 and 0, respectively. 
df['sentiment'].replace(['POSITIVE','NEGATIVE'],[1,0],inplace=True)
df['sentiment'].value_counts() 
#value_counts() method is used to count the number of occurrences of each unique value in the sentiment column.
# Out:
# 0    29988
# 1    29985
# Name: sentiment, dtype: int64

# %%
Y=list(df['sentiment'])
train_y=Y[:len(Y)-6000]
test_y=Y[-6000:]
print(len(train_y),len(test_y))
# Out:
# 53973 6000

# %%
train_indices=np.asarray(train_indices)
train_y=np.asarray(train_y)

# %%
test_indices=tokenizer.texts_to_sequences(test_text)
test_indices=pad_sequences(test_indices,maxlen=max_length,padding='post')
test_indices=np.asarray(test_indices)
test_y=np.asarray(test_y)

# %% [markdown]
# # Sequential Models

# %% [markdown]
# Sequential() is a class in the Keras API for building a sequential model in deep learning. The model is a linear stack of layers where each layer is connected to the next layer, forming a sequence of layers.
#
# The Sequential() function initializes an empty sequential model object that can be used to add layers one after the other. Once we have created the model using Sequential(), we can add layers to the model using the add() method.

# %% [markdown]
# # SimpleRNN

# %%
# defining a sequential neural network model using the Keras API
vocab= len(tokenizer.word_index)+1 #calculates the vocabulary size of the input data 
modelRNN= Sequential()
modelRNN.add(Embedding(input_dim=vocab,output_dim=100,input_length=max_length)) #input sequences of integers as input and converts them into dense vectors of fixed size
modelRNN.add(Dropout(0.3))# dropping at input level to prevent overfitting
modelRNN.add(SimpleRNN(32))#SimpleRNN layer has 32 units, which determines the dimensionality of the internal state.
modelRNN.add(Dropout(0.3))# another drop out layer added after RNN to prevent overfitting
modelRNN.add(Dense(1, activation='sigmoid'))#fully connected layer that produces a single output value between 0 and 1 with use of sigmoid function
modelRNN.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#compile() method is used to compile the model, specifying the loss function ('binary_crossentropy'), the optimizer ('adam'),
# and the evaluation metric ('accuracy').

print(modelRNN.summary())# print a summary of the model architecture
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 64, 100)           2675900
#
#  dropout_6 (Dropout)         (None, 64, 100)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                4256
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,680,189
# Trainable params: 2,680,189
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# *train_indices is the input data for the model, typically a set of training examples that have been converted into numerical features.
#
# *train_y is the output data for the model, which typically consists of labels or target values that the model is trying to predict.
#
# *epochs specifies the number of times the model will iterate over the entire training dataset during training. Each iteration over the dataset is called an epoch.
#
# *batch_size specifies the number of training examples that the model will use at once to update its parameters during each epoch. The model will use mini-batch stochastic gradient descent to optimize the parameters.
#
# *validation_split specifies the proportion of the training data that will be used for validation during training. In this case, 20% of the training data will be used for validation, and the remaining 80% will be used for actual training.

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping
history = modelRNN.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = modelRNN.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelRNN.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelRNN.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Generate classification report
print("SimpleRNN classification_report:\n",classification_report(test_y, test_pred_classes))

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy of SimpleRNN:', train_acc)
print('Test Accuracy of SimpleRNN:', test_acc)
print('Precision of SimpleRNN:', precision)
print('Recall of SimpleRNN:', recall)
print('F1 Score of SimpleRNN:', f1)
print('AUC Score:', auc_score)
# Out:
# Epoch 1/10
# 1350/1350 [==============================] - 50s 36ms/step - loss: 0.6310 - accuracy: 0.6567 - val_loss: 0.5707 - val_accuracy: 0.7231
# Epoch 2/10
# 1350/1350 [==============================] - 47s 35ms/step - loss: 0.5675 - accuracy: 0.7236 - val_loss: 0.5698 - val_accuracy: 0.7206
# Epoch 3/10
# 1350/1350 [==============================] - 52s 39ms/step - loss: 0.4927 - accuracy: 0.7789 - val_loss: 0.5716 - val_accuracy: 0.7255
# Epoch 4/10
# 1350/1350 [==============================] - 67s 49ms/step - loss: 0.4465 - accuracy: 0.8054 - val_loss: 0.5786 - val_accuracy: 0.7155
# Epoch 5/10
# 1350/1350 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8240Restoring model weights from the end of the best epoch: 2.
# 1350/1350 [==============================] - 80s 59ms/step - loss: 0.4105 - accuracy: 0.8240 - val_loss: 0.6201 - val_accuracy: 0.7182
# Epoch 5: early stopping
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5703 - accuracy: 0.7162
# 188/188 [==============================] - 1s 4ms/step
# 1687/1687 [==============================] - 8s 4ms/step
# SimpleRNN classification_report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72      3080
#            1       0.71      0.71      0.71      2920
#
#     accuracy                           0.72      6000
#    macro avg       0.72      0.72      0.72      6000
# weighted avg       0.72      0.72      0.72      6000
#
# Train Accuracy of SimpleRNN: 0.7852259463064866
# Test Accuracy of SimpleRNN: 0.7161666666666666
# Precision of SimpleRNN: 0.7059221658206429
# Recall of SimpleRNN: 0.7143835616438357
# F1 Score of SimpleRNN: 0.7101276595744681
# AUC Score: 0.7753021593132895

# %%
# Calculate confusion matrix
conf_mat = confusion_matrix(test_y, test_pred_classes)
sns.heatmap(conf_mat, annot=True, fmt='g', cmap='Blues')
plt.title('SimpleRNN Confusion Matrix')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='SimpleRNN (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.layers import ReLU

vocab = len(tokenizer.word_index) + 1
modelLSTM = Sequential()
modelLSTM.add(Embedding(input_dim=vocab, output_dim=100, input_length=max_length))
modelLSTM.add(Dropout(0.1))
modelLSTM.add(LSTM(32))
modelLSTM.add(Dropout(0.1))
modelLSTM.add(Dense(1))
modelLSTM.add(ReLU())
modelLSTM.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(modelLSTM.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 64, 100)           2675900
#
#  dropout (Dropout)           (None, 64, 100)           0
#
#  lstm (LSTM)                 (None, 32)                17024
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
#  re_lu (ReLU)                (None, 1)                 0
#
# =================================================================
# Total params: 2,692,957
# Trainable params: 2,692,957
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping
history = modelLSTM.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = modelLSTM.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelLSTM.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelLSTM.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Generate classification report
print(classification_report(test_y, test_pred_classes))

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy of LSTM model:', train_acc)
print('Test Accuracy of LSTM model:', test_acc)
print('Precision of LSTM model:', precision)
print('Recall of LSTM model:', recall)
print('F1 Score of LSTM model:', f1)
print('AUC Score of LSTM model:', auc_score)
# Out:
# Epoch 1/10
# 1350/1350 [==============================] - 104s 74ms/step - loss: 0.7016 - accuracy: 0.5023 - val_loss: 0.6931 - val_accuracy: 0.5066
# Epoch 2/10
# 1350/1350 [==============================] - 98s 72ms/step - loss: 0.6970 - accuracy: 0.4983 - val_loss: 0.6931 - val_accuracy: 0.5066
# Epoch 3/10
# 1350/1350 [==============================] - 101s 75ms/step - loss: 0.7005 - accuracy: 0.5273 - val_loss: 0.6333 - val_accuracy: 0.6602
# Epoch 4/10
# 1350/1350 [==============================] - 110s 81ms/step - loss: 0.5663 - accuracy: 0.7252 - val_loss: 0.5458 - val_accuracy: 0.7278
# Epoch 5/10
# 1350/1350 [==============================] - 113s 84ms/step - loss: 0.5375 - accuracy: 0.7366 - val_loss: 0.5427 - val_accuracy: 0.7364
# Epoch 6/10
# 1350/1350 [==============================] - 111s 82ms/step - loss: 0.4362 - accuracy: 0.8219 - val_loss: 0.5376 - val_accuracy: 0.7381
# Epoch 7/10
# 1350/1350 [==============================] - 99s 74ms/step - loss: 0.3868 - accuracy: 0.8518 - val_loss: 0.5371 - val_accuracy: 0.7494
# Epoch 8/10
# 1350/1350 [==============================] - 98s 72ms/step - loss: 0.3757 - accuracy: 0.8597 - val_loss: 0.7341 - val_accuracy: 0.5066
# Epoch 9/10
# 1350/1350 [==============================] - 96s 71ms/step - loss: 0.3698 - accuracy: 0.8337 - val_loss: 0.5550 - val_accuracy: 0.7533
# Epoch 10/10
# 1350/1350 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.7524Restoring model weights from the end of the best epoch: 7.
# 1350/1350 [==============================] - 99s 73ms/step - loss: 0.4634 - accuracy: 0.7524 - val_loss: 0.6844 - val_accuracy: 0.5491
# Epoch 10: early stopping
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5205 - accuracy: 0.7612
# 188/188 [==============================] - 3s 9ms/step
# 1687/1687 [==============================] - 17s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76      3080
#            1       0.75      0.77      0.76      2920
#
#     accuracy                           0.76      6000
#    macro avg       0.76      0.76      0.76      6000
# weighted avg       0.76      0.76      0.76      6000
#
# Train Accuracy of LSTM model: 0.8652659663164916
# Test Accuracy of LSTM model: 0.7611666666666667
# Precision of LSTM model: 0.7454605480356553
# Recall of LSTM model: 0.7732876712328767
# F1 Score of LSTM model: 0.7591191796940662
# AUC Score of LSTM model: 0.8341171499733143

# %%
# Calculate confusion matrix
conf_mat = confusion_matrix(test_y, test_pred_classes)
sns.heatmap(conf_mat, annot=True, fmt='g', cmap='Blues')
plt.title('LSTM Confusion Matrix')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='LSTM (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# #  Bidirectional RNN

# %%
## Layer normalization is another regularization technique used to prevent overfitting by normalizing 
## the activations of the neurons in the layer

### Strengthening using bidirectional SimpleRNN

vocab= len(tokenizer.word_index)+1#calculates the vocabulary size of the input data 
modelbidr= Sequential()
modelbidr.add(Embedding(input_dim=vocab,output_dim=100,input_length=max_length))#input sequences of integers as input and converts them into dense vectors of fixed size
modelbidr.add(Dropout(0.3))# dropping at input level to prevent overfitting
modelbidr.add(Bidirectional(SimpleRNN(32)))#adds a Bidirectional SimpleRNN layer to the model.
modelbidr.add(LayerNormalization()) #dds a LayerNormalization layer to the model
modelbidr.add(Dropout(0.3))#adds another dropout layer after the layer Normalisation layer to further prevent overfitting
modelbidr.add(Dense(1, activation='sigmoid'))#fully connected layer that produces a single output value between 0 and 1 with use of sigmoid function
modelbidr.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(modelbidr.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 64, 100)           2675900
#
#  dropout_14 (Dropout)        (None, 64, 100)           0
#
#  bidirectional_5 (Bidirectio  (None, 64)               8512
#  nal)
#
#  layer_normalization_3 (Laye  (None, 64)               128
#  rNormalization)
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,684,605
# Trainable params: 2,684,605
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping
history = modelbidr.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
test_loss, test_acc = modelbidr.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelbidr.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelbidr.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Generate classification report
print("Bidirectional RNN classification_report:\n",classification_report(test_y, test_pred_classes))

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy of Bidirectional RNN model:', train_acc)
print('Test Accuracy of Bidirectional RNN model:', test_acc)
print('Precision of Bidirectional RNN model:', precision)
print('Recall of Bidirectional RNN model:', recall)
print('F1 Score of Bidirectional RNN model:', f1)
print('AUC Score:', auc_score)
# Out:
# Epoch 1/10
# 1350/1350 [==============================] - 102s 73ms/step - loss: 0.6029 - accuracy: 0.6715 - val_loss: 0.5074 - val_accuracy: 0.7446
# Epoch 2/10
# 1350/1350 [==============================] - 94s 70ms/step - loss: 0.4103 - accuracy: 0.8162 - val_loss: 0.5251 - val_accuracy: 0.7424
# Epoch 3/10
# 1350/1350 [==============================] - 98s 73ms/step - loss: 0.2911 - accuracy: 0.8791 - val_loss: 0.6077 - val_accuracy: 0.7315
# Epoch 4/10
# 1350/1350 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9182Restoring model weights from the end of the best epoch: 1.
# 1350/1350 [==============================] - 96s 71ms/step - loss: 0.2092 - accuracy: 0.9182 - val_loss: 0.6941 - val_accuracy: 0.7253
# Epoch 4: early stopping
# 188/188 [==============================] - 2s 11ms/step - loss: 0.5062 - accuracy: 0.7472
# 188/188 [==============================] - 2s 8ms/step
# 1687/1687 [==============================] - 13s 8ms/step
# Bidirectional RNN classification_report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75      3080
#            1       0.73      0.76      0.74      2920
#
#     accuracy                           0.75      6000
#    macro avg       0.75      0.75      0.75      6000
# weighted avg       0.75      0.75      0.75      6000
#
# Train Accuracy of Bidirectional RNN model: 0.8185944824263984
# Test Accuracy of Bidirectional RNN model: 0.7471666666666666
# Precision of Bidirectional RNN model: 0.7326699834162521
# Recall of Bidirectional RNN model: 0.7565068493150685
# F1 Score of Bidirectional RNN model: 0.7443976411120472
# AUC Score: 0.8314686554883474

# %%
# Calculate confusion matrix
conf_mat = confusion_matrix(test_y, test_pred_classes)
sns.heatmap(conf_mat, annot=True, fmt='g', cmap='Blues')
plt.title('Bidirectional RNN Confusion Matrix')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='Bidirectional RNN (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
