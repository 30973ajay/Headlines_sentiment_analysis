# %%
import os
import pandas as pd
import numpy as np

##tensorflow modules
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Embedding, Dense, SimpleRNN, LSTM, Dropout, BatchNormalization
from tensorflow.keras.layers import Bidirectional,LayerNormalization

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint


## text preprocessing modules
from gensim.parsing.preprocessing import remove_stopwords
from gensim.models import Word2Vec
import re
import nltk
nltk.download('punkt')
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, precision_score, recall_score, f1_score,auc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, BatchNormalization, Dropout, Embedding, LayerNormalization, Bidirectional
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('Sentiment_news_dataframe.csv')
df.head()
# Out:
#        Date                                              Title  \
# 0  03/10/17        Amber Enterprises files for Rs555 crore IPO
# 1  21/04/18  No need to divorce this stock ; brokerage sees...
# 2  11/07/18  An evening walk down Dalal Street : Trade war ...
# 3  09/01/20  Commodity outlook : Refined soya oil jumps 8 %...
# 4  19/04/17  Nikkei : Tokyo stocks open lower after British...
#
#                                                  URL sentiment  confidence  \
# 0  http://www.livemint.com/Money/DJCTYXYzpDnVT1Ki...  NEGATIVE   -0.987213
# 1  https://www.moneycontrol.com/news/business/sto...  POSITIVE    0.946583
# 2  https://www.moneycontrol.com/news/business/mar...  POSITIVE    0.967994
# 3  https://economictimes.indiatimes.com/markets/c...  NEGATIVE   -0.879617
# 4  http://economictimes.indiatimes.com/markets/st...  NEGATIVE   -0.941918
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Dropping Columns not required

# %%
df = df.drop(['Date','URL','confidence','Unnamed: 5'], axis=1)
df.head()
# Out:
#                                                Title sentiment
# 0        Amber Enterprises files for Rs555 crore IPO  NEGATIVE
# 1  No need to divorce this stock ; brokerage sees...  POSITIVE
# 2  An evening walk down Dalal Street : Trade war ...  POSITIVE
# 3  Commodity outlook : Refined soya oil jumps 8 %...  NEGATIVE
# 4  Nikkei : Tokyo stocks open lower after British...  NEGATIVE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      60000 non-null  object
#  1   sentiment  60000 non-null  object
# dtypes: object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# Check for null values

# %%
df.isnull().sum()
# Out:
# Title        0
# sentiment    0
# dtype: int64

# %% [markdown]
# Drop Duplicates

# %%
df = df.drop_duplicates(subset=["Title"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59973 entries, 0 to 59999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      59973 non-null  object
#  1   sentiment  59973 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
headline= list(df['Title'])
headline[0:2]
# Out:
# ['Amber Enterprises files for Rs555 crore IPO',
#  'No need to divorce this stock ; brokerage sees up to 26 % upside on this wedding portal']

# %%
### Basic text preprocessing where we remove special characters, any tags etc
#### Removal of stopwords
#### Removal of tags
#### Removal of special characters
#### Removal of email id
#### Removal of numbers
text=[]
for r in headline:
  r = re.sub(r'<.*?>',"",r)
  r = re.sub(r'\S+@\S+\s','',r)
  r = re.sub(r'\d+','',r)
  r = re.sub(r'[#$!\*\)\(\\%:;,\'_-]','',r)
  text.append(remove_stopwords(r))

text[0:3]
# Out:
# ['Amber Enterprises files Rs crore IPO',
#  'No need divorce stock brokerage sees upside wedding portal',
#  'An evening walk Dalal Street Trade war fears grips equity markets globe Nifty ends']

# %% [markdown]
# # Tokenisation

# %%
### Now the reviews are faily clean, we will tokenize the reviews and get word embeddings for these
tokenizer=Tokenizer(num_words=15000,lower=True,oov_token='UNK')# out of vocabulory-oov

# %% [markdown]
# Train test split

# %%
## Before applying the tokenizer, lets split the data into train test
train_text=text[:len(text)-500]
test_text=text[-500:]
print(len(text),len(train_text),len(test_text))
# Out:
# 59973 59473 500

# %%
### Now lets tokenize the reviews
tokenizer.fit_on_texts(train_text)

# %%
tokenizer.word_index
# Out:
# {'UNK': 1,
#  'india': 2,
#  'market': 3,
#  'rs': 4,
#  'us': 5,
#  'stocks': 6,
#  'says': 7,
#  'sensex': 8,
#  'nifty': 9,
#  'the': 10,
#  'bank': 11,
#  'growth': 12,
#  'rbi': 13,
#  'china': 14,
#  'economy': 15,
#  'trade': 16,
#  'indian': 17,
#  'live': 18,
#  'new': 19,
#  'markets': 20,
#  'modi': 21,
#  'budget': 22,
#  'news': 23,
#  'global': 24,
#  'crore': 25,
#  'stock': 26,
#  'gold': 27,
#  'financial': 28,
#  'oil': 29,
#  'price': 30,
#  'rupee': 31,
#  'trump': 32,
#  'prices': 33,
#  'economic': 34,
#  'covid': 35,
#  'govt': 36,
#  'buy': 37,
#  'today': 38,
#  'dollar': 39,
#  'q': 40,
#  'share': 41,
#  'sebi': 42,
#  'rate': 43,
#  'year': 44,
#  'coronavirus': 45,
#  'express': 46,
#  'how': 47,
#  'high': 48,
#  'report': 49,
#  'fund': 50,
#  'pm': 51,
#  'business': 52,
#  'investors': 53,
#  'policy': 54,
#  'tax': 55,
#  'government': 56,
#  'week': 57,
#  'day': 58,
#  'shares': 59,
#  'mutual': 60,
#  'street': 61,
#  'world': 62,
#  'funds': 63,
#  'gst': 64,
#  'time': 65,
#  'fy': 66,
#  'likely': 67,
#  'gdp': 68,
#  'ahead': 69,
#  'investment': 70,
#  'higher': 71,
#  'why': 72,
#  'billion': 73,
#  'years': 74,
#  'points': 75,
#  'cut': 76,
#  'ipo': 77,
#  'में': 78,
#  'sector': 79,
#  'a': 80,
#  'data': 81,
#  'banks': 82,
#  'rise': 83,
#  'what': 84,
#  'gains': 85,
#  'demand': 86,
#  'inflation': 87,
#  'hit': 88,
#  'lakh': 89,
#  'fall': 90,
#  'set': 91,
#  'amid': 92,
#  'big': 93,
#  'donald': 94,
#  'key': 95,
#  'focus': 96,
#  'impact': 97,
#  'record': 98,
#  'ltd': 99,
#  'sell': 100,
#  'here': 101,
#  'asian': 102,
#  'rates': 103,
#  'cr': 104,
#  'fed': 105,
#  'sales': 106,
#  'tata': 107,
#  'deal': 108,
#  'rally': 109,
#  'invest': 110,
#  'bse': 111,
#  'rises': 112,
#  'low': 113,
#  'capital': 114,
#  'finance': 115,
#  'companies': 116,
#  'target': 117,
#  'sbi': 118,
#  'it': 119,
#  'nse': 120,
#  'crude': 121,
#  'boost': 122,
#  'lower': 123,
#  'open': 124,
#  'narendra': 125,
#  'need': 126,
#  'money': 127,
#  'end': 128,
#  'million': 129,
#  'profit': 130,
#  'के': 131,
#  'hits': 132,
#  'earnings': 133,
#  'in': 134,
#  'auto': 135,
#  'outlook': 136,
#  'month': 137,
#  'debt': 138,
#  'fiscal': 139,
#  'crisis': 140,
#  'industry': 141,
#  'good': 142,
#  'term': 143,
#  'recovery': 144,
#  'asia': 145,
#  'ceo': 146,
#  'jobs': 147,
#  'tech': 148,
#  'falls': 149,
#  'war': 150,
#  'plans': 151,
#  'equity': 152,
#  'post': 153,
#  's': 154,
#  'bond': 155,
#  'd': 156,
#  'podcast': 157,
#  'pharma': 158,
#  'cuts': 159,
#  'real': 160,
#  'meet': 161,
#  'launch': 162,
#  'power': 163,
#  'th': 164,
#  'steel': 165,
#  'help': 166,
#  'paise': 167,
#  'lockdown': 168,
#  'digital': 169,
#  'plan': 170,
#  'long': 171,
#  'hdfc': 172,
#  'की': 173,
#  'experts': 174,
#  'times': 175,
#  'retail': 176,
#  'offers': 177,
#  'know': 178,
#  'wall': 179,
#  'jaitley': 180,
#  'credit': 181,
#  'strong': 182,
#  'm': 183,
#  'fm': 184,
#  'g': 185,
#  'firms': 186,
#  'view': 187,
#  'support': 188,
#  'demonetisation': 189,
#  'raise': 190,
#  'march': 191,
#  'sees': 192,
#  'needs': 193,
#  'risk': 194,
#  'services': 195,
#  'survey': 196,
#  'foreign': 197,
#  'chief': 198,
#  'minister': 199,
#  'investments': 200,
#  'election': 201,
#  'pandemic': 202,
#  'hold': 203,
#  'hike': 204,
#  'check': 205,
#  'arun': 206,
#  'opens': 207,
#  'congress': 208,
#  'despite': 209,
#  'gets': 210,
#  'slowdown': 211,
#  'months': 212,
#  'f': 213,
#  'pts': 214,
#  'trading': 215,
#  'o': 216,
#  'reliance': 217,
#  'top': 218,
#  'will': 219,
#  'exports': 220,
#  'gain': 221,
#  'united': 222,
#  'bjp': 223,
#  'sitharaman': 224,
#  'yes': 225,
#  'president': 226,
#  'p': 227,
#  'talks': 228,
#  'june': 229,
#  'loan': 230,
#  'launches': 231,
#  'icici': 232,
#  'k': 233,
#  'net': 234,
#  'small': 235,
#  'saudi': 236,
#  'bonds': 237,
#  'soon': 238,
#  'union': 239,
#  'online': 240,
#  'continue': 241,
#  'stimulus': 242,
#  'trillion': 243,
#  'securities': 244,
#  'to': 245,
#  'delhi': 246,
#  'may': 247,
#  'fresh': 248,
#  'income': 249,
#  'chinese': 250,
#  'ril': 251,
#  'april': 252,
#  'after': 253,
#  'near': 254,
#  'results': 255,
#  'motors': 256,
#  'eyes': 257,
#  'weak': 258,
#  'expect': 259,
#  'start': 260,
#  'moneycontrol': 261,
#  'factors': 262,
#  'estate': 263,
#  'tips': 264,
#  'state': 265,
#  'hopes': 266,
#  'return': 267,
#  'cash': 268,
#  'quotes': 269,
#  'best': 270,
#  'centre': 271,
#  'future': 272,
#  'से': 273,
#  'group': 274,
#  'better': 275,
#  'stake': 276,
#  'is': 277,
#  'look': 278,
#  'raises': 279,
#  'things': 280,
#  'biggest': 281,
#  'remain': 282,
#  'imf': 283,
#  'firm': 284,
#  'का': 285,
#  'infosys': 286,
#  'corporate': 287,
#  'industries': 288,
#  'ends': 289,
#  'reforms': 290,
#  'japan': 291,
#  'opinion': 292,
#  'pakistan': 293,
#  'slips': 294,
#  'job': 295,
#  'mahindra': 296,
#  'bids': 297,
#  'dont': 298,
#  'no': 299,
#  'rising': 300,
#  'returns': 301,
#  'bell': 302,
#  'kotak': 303,
#  'portfolio': 304,
#  'singh': 305,
#  'flat': 306,
#  'brexit': 307,
#  'revenue': 308,
#  'positive': 309,
#  'morning': 310,
#  'housing': 311,
#  'highs': 312,
#  'push': 313,
#  'quarter': 314,
#  'cues': 315,
#  'etmarkets': 316,
#  'opening': 317,
#  'apple': 318,
#  'vs': 319,
#  'expected': 320,
#  'ban': 321,
#  'korea': 322,
#  'this': 323,
#  'life': 324,
#  'equities': 325,
#  'energy': 326,
#  'rahul': 327,
#  'for': 328,
#  'seeks': 329,
#  'sale': 330,
#  'second': 331,
#  'iran': 332,
#  'grow': 333,
#  'change': 334,
#  'home': 335,
#  'gandhi': 336,
#  'consumer': 337,
#  'surge': 338,
#  'lead': 339,
#  'review': 340,
#  'mark': 341,
#  'monetary': 342,
#  'banking': 343,
#  'पर': 344,
#  'deficit': 345,
#  'kingdom': 346,
#  'central': 347,
#  'supply': 348,
#  'we': 349,
#  'jumps': 350,
#  'sectors': 351,
#  'amazon': 352,
#  'tv': 353,
#  'seen': 354,
#  'cent': 355,
#  'private': 356,
#  'short': 357,
#  'wealth': 358,
#  'fears': 359,
#  'बाजार': 360,
#  'work': 361,
#  'stay': 362,
#  'cap': 363,
#  'as': 364,
#  'fpis': 365,
#  'december': 366,
#  'right': 367,
#  'people': 368,
#  'july': 369,
#  'silver': 370,
#  'opec': 371,
#  'elections': 372,
#  'index': 373,
#  'insurance': 374,
#  'investing': 375,
#  'mf': 376,
#  'shah': 377,
#  'rural': 378,
#  'like': 379,
#  'value': 380,
#  'issue': 381,
#  'company': 382,
#  'way': 383,
#  'north': 384,
#  'tcs': 385,
#  'inc': 386,
#  'early': 387,
#  'nirmala': 388,
#  'manufacturing': 389,
#  'dalal': 390,
#  'drive': 391,
#  'moody': 392,
#  'september': 393,
#  'steady': 394,
#  'maruti': 395,
#  'case': 396,
#  'offer': 397,
#  'air': 398,
#  'investor': 399,
#  'office': 400,
#  'airtel': 401,
#  'states': 402,
#  'governor': 403,
#  'international': 404,
#  'note': 405,
#  'bad': 406,
#  'latest': 407,
#  'bitcoin': 408,
#  'projects': 409,
#  'create': 410,
#  'watch': 411,
#  'google': 412,
#  'bn': 413,
#  'major': 414,
#  'farmers': 415,
#  'bharat': 416,
#  'e': 417,
#  'days': 418,
#  'poll': 419,
#  'list': 420,
#  'with': 421,
#  'loans': 422,
#  'double': 423,
#  'output': 424,
#  'pay': 425,
#  'ideas': 426,
#  'forecast': 427,
#  'august': 428,
#  'emerging': 429,
#  'i': 430,
#  'issues': 431,
#  'virus': 432,
#  'measures': 433,
#  'south': 434,
#  'taking': 435,
#  'liquidity': 436,
#  'asset': 437,
#  'food': 438,
#  'bajaj': 439,
#  'far': 440,
#  'worth': 441,
#  'bullish': 442,
#  'meeting': 443,
#  'calls': 444,
#  'chairman': 445,
#  'futures': 446,
#  't': 447,
#  'ease': 448,
#  'drop': 449,
#  'analysts': 450,
#  'cases': 451,
#  'maharashtra': 452,
#  'buying': 453,
#  'health': 454,
#  'concerns': 455,
#  'idea': 456,
#  'risks': 457,
#  'takes': 458,
#  'kumar': 459,
#  'psu': 460,
#  'norms': 461,
#  'close': 462,
#  'electric': 463,
#  'vaccine': 464,
#  'losses': 465,
#  'है': 466,
#  'from': 467,
#  'run': 468,
#  'turn': 469,
#  'rules': 470,
#  'farm': 471,
#  'rating': 472,
#  'space': 473,
#  'asks': 474,
#  'come': 475,
#  'led': 476,
#  'level': 477,
#  'looks': 478,
#  'public': 479,
#  'realty': 480,
#  'signs': 481,
#  'looking': 482,
#  'jet': 483,
#  'jio': 484,
#  'midcap': 485,
#  'शेयर': 486,
#  'october': 487,
#  'सेंसेक्स': 488,
#  'ministry': 489,
#  'mid': 490,
#  'country': 491,
#  'now': 492,
#  'worst': 493,
#  'axis': 494,
#  'summit': 495,
#  'show': 496,
#  'bets': 497,
#  'mumbai': 498,
#  'board': 499,
#  'amc': 500,
#  'november': 501,
#  'of': 502,
#  'should': 503,
#  'warns': 504,
#  'domestic': 505,
#  'increase': 506,
#  'fuel': 507,
#  'want': 508,
#  'strategy': 509,
#  'cost': 510,
#  'niti': 511,
#  'january': 512,
#  'products': 513,
#  'yields': 514,
#  'jump': 515,
#  'st': 516,
#  'picks': 517,
#  'bet': 518,
#  'usd': 519,
#  'wants': 520,
#  'infrastructure': 521,
#  'commodity': 522,
#  'loss': 523,
#  'relief': 524,
#  'shows': 525,
#  'green': 526,
#  'all': 527,
#  'ready': 528,
#  'volatility': 529,
#  'uber': 530,
#  'package': 531,
#  'traders': 532,
#  'scheme': 533,
#  'making': 534,
#  'l': 535,
#  'nearly': 536,
#  'makes': 537,
#  'national': 538,
#  'reserve': 539,
#  'women': 540,
#  'biden': 541,
#  'cnbc': 542,
#  'arvind': 543,
#  'ties': 544,
#  'biz': 545,
#  'free': 546,
#  'infra': 547,
#  'story': 548,
#  'can': 549,
#  'these': 550,
#  'gainers': 551,
#  'extends': 552,
#  'play': 553,
#  'face': 554,
#  'nbfcs': 555,
#  'drops': 556,
#  'use': 557,
#  'indians': 558,
#  'tensions': 559,
#  'coming': 560,
#  'track': 561,
#  'assets': 562,
#  'aayog': 563,
#  'surges': 564,
#  'deals': 565,
#  'updates': 566,
#  'currency': 567,
#  'panel': 568,
#  'worries': 569,
#  'action': 570,
#  'midcaps': 571,
#  'cities': 572,
#  'announces': 573,
#  'on': 574,
#  'consumption': 575,
#  'production': 576,
#  'suzuki': 577,
#  'export': 578,
#  'pnb': 579,
#  'xi': 580,
#  'dips': 581,
#  'development': 582,
#  'holds': 583,
#  'february': 584,
#  'facebook': 585,
#  'house': 586,
#  'startups': 587,
#  'climate': 588,
#  'cm': 589,
#  'steps': 590,
#  'funding': 591,
#  'pick': 592,
#  'opportunity': 593,
#  'ने': 594,
#  'working': 595,
#  'edge': 596,
#  'going': 597,
#  'airways': 598,
#  'petrol': 599,
#  'expects': 600,
#  'samsung': 601,
#  'h': 602,
#  'benefit': 603,
#  'un': 604,
#  'highest': 605,
#  'startup': 606,
#  'cement': 607,
#  'decision': 608,
#  'growing': 609,
#  'eu': 610,
#  'repo': 611,
#  'fmcg': 612,
#  'numbers': 613,
#  'polls': 614,
#  'goyal': 615,
#  'metal': 616,
#  'tariffs': 617,
#  'mobile': 618,
#  'fight': 619,
#  'recession': 620,
#  'sun': 621,
#  'base': 622,
#  'season': 623,
#  'gujarat': 624,
#  'up': 625,
#  'pressure': 626,
#  'largest': 627,
#  'spending': 628,
#  'monday': 629,
#  'walk': 630,
#  'security': 631,
#  'woes': 632,
#  'slip': 633,
#  'को': 634,
#  'road': 635,
#  'half': 636,
#  'inflows': 637,
#  'political': 638,
#  'wont': 639,
#  'gas': 640,
#  'sanctions': 641,
#  'businesses': 642,
#  'technology': 643,
#  'european': 644,
#  'potential': 645,
#  'तेजी': 646,
#  'imports': 647,
#  'patel': 648,
#  'exit': 649,
#  'build': 650,
#  'study': 651,
#  'management': 652,
#  'expectations': 653,
#  'nod': 654,
#  'reasons': 655,
#  'decline': 656,
#  'bps': 657,
#  'ambani': 658,
#  'tops': 659,
#  'md': 660,
#  'status': 661,
#  'arabia': 662,
#  'healthcare': 663,
#  'challenges': 664,
#  'order': 665,
#  'itc': 666,
#  'remains': 667,
#  'car': 668,
#  'australia': 669,
#  'bring': 670,
#  'cars': 671,
#  'secretary': 672,
#  'movers': 673,
#  'official': 674,
#  'levels': 675,
#  'head': 676,
#  'chidambaram': 677,
#  'uk': 678,
#  'ratings': 679,
#  'media': 680,
#  'bulls': 681,
#  'non': 682,
#  'away': 683,
#  'diesel': 684,
#  'till': 685,
#  'revival': 686,
#  'eases': 687,
#  'pre': 688,
#  'das': 689,
#  'trades': 690,
#  'msmes': 691,
#  'special': 692,
#  'monsoon': 693,
#  'premium': 694,
#  'continues': 695,
#  'hikes': 696,
#  'spot': 697,
#  'sentiment': 698,
#  'piyush': 699,
#  'macro': 700,
#  'schemes': 701,
#  'overseas': 702,
#  'flipkart': 703,
#  'session': 704,
#  'an': 705,
#  'evening': 706,
#  'win': 707,
#  'based': 708,
#  'orders': 709,
#  'bharti': 710,
#  'stop': 711,
#  'closes': 712,
#  'revive': 713,
#  'commerce': 714,
#  'step': 715,
#  'telecom': 716,
#  'u': 717,
#  'sets': 718,
#  'details': 719,
#  'over': 720,
#  'court': 721,
#  'fpi': 722,
#  'mpc': 723,
#  'countries': 724,
#  'friday': 725,
#  'industrial': 726,
#  'singapore': 727,
#  'posts': 728,
#  'factory': 729,
#  'visit': 730,
#  'goods': 731,
#  'large': 732,
#  'mn': 733,
#  'cautious': 734,
#  'subramanian': 735,
#  'trend': 736,
#  'russia': 737,
#  'mukesh': 738,
#  'dip': 739,
#  'slump': 740,
#  'activity': 741,
#  'more': 742,
#  'adani': 743,
#  'slow': 744,
#  'smart': 745,
#  'wednesday': 746,
#  'closing': 747,
#  'travel': 748,
#  'federal': 749,
#  'pradesh': 750,
#  'add': 751,
#  'amit': 752,
#  'highlights': 753,
#  'update': 754,
#  'technical': 755,
#  'leaders': 756,
#  'indices': 757,
#  'seek': 758,
#  'faces': 759,
#  'bull': 760,
#  'coal': 761,
#  'improve': 762,
#  'sabha': 763,
#  'expansion': 764,
#  'point': 765,
#  'karnataka': 766,
#  'series': 767,
#  'workers': 768,
#  'europe': 769,
#  'project': 770,
#  'reach': 771,
#  'education': 772,
#  'role': 773,
#  'local': 774,
#  'gives': 775,
#  'party': 776,
#  'touch': 777,
#  'smartphone': 778,
#  'kashmir': 779,
#  'test': 780,
#  'motilal': 781,
#  'lending': 782,
#  'lose': 783,
#  'fdi': 784,
#  'metals': 785,
#  'mixed': 786,
#  'oswal': 787,
#  'unlikely': 788,
#  'defence': 789,
#  'moves': 790,
#  'payments': 791,
#  'v': 792,
#  'current': 793,
#  'reform': 794,
#  'not': 795,
#  'agriculture': 796,
#  'buys': 797,
#  'urges': 798,
#  'quality': 799,
#  'forms': 800,
#  'aims': 801,
#  'council': 802,
#  'hero': 803,
#  'address': 804,
#  'urjit': 805,
#  'policies': 806,
#  'changed': 807,
#  'rajan': 808,
#  'duty': 809,
#  'dr': 810,
#  'extend': 811,
#  'options': 812,
#  'negative': 813,
#  'thursday': 814,
#  'are': 815,
#  'challenge': 816,
#  'volatile': 817,
#  'social': 818,
#  'city': 819,
#  'b': 820,
#  'avoid': 821,
#  'possible': 822,
#  'nitin': 823,
#  'gadkari': 824,
#  'हैं': 825,
#  'morgan': 826,
#  'hotels': 827,
#  'और': 828,
#  'टुडे': 829,
#  'visa': 830,
#  'shaktikanta': 831,
#  'act': 832,
#  'range': 833,
#  'import': 834,
#  'selling': 835,
#  'tells': 836,
#  'शेयरों': 837,
#  'correction': 838,
#  'one': 839,
#  'xiaomi': 840,
#  'festive': 841,
#  'et': 842,
#  'bengaluru': 843,
#  'listing': 844,
#  'tomorrow': 845,
#  'jinping': 846,
#  'at': 847,
#  'needed': 848,
#  'रेट': 849,
#  'iphone': 850,
#  'book': 851,
#  'costs': 852,
#  'crash': 853,
#  'dow': 854,
#  'बैंक': 855,
#  'plant': 856,
#  'forex': 857,
#  'reports': 858,
#  'account': 859,
#  'क्या': 860,
#  'threat': 861,
#  'euro': 862,
#  'momentum': 863,
#  'wipro': 864,
#  'rebound': 865,
#  'rallies': 866,
#  'launched': 867,
#  'service': 868,
#  'great': 869,
#  'edelweiss': 870,
#  'effect': 871,
#  'daily': 872,
#  'pmi': 873,
#  'brand': 874,
#  'falling': 875,
#  'kong': 876,
#  'exchange': 877,
#  'vodafone': 878,
#  'tariff': 879,
#  'speech': 880,
#  'signals': 881,
#  'weekly': 882,
#  'turns': 883,
#  'cards': 884,
#  'savings': 885,
#  'changes': 886,
#  'hong': 887,
#  'getting': 888,
#  'units': 889,
#  'straight': 890,
#  'reddy': 891,
#  'your': 892,
#  'अंक': 893,
#  'platform': 894,
#  'merger': 895,
#  'edges': 896,
#  'opportunities': 897,
#  'indigo': 898,
#  'eye': 899,
#  'sharma': 900,
#  'white': 901,
#  'fitch': 902,
#  'keeps': 903,
#  'reduce': 904,
#  'easing': 905,
#  'motor': 906,
#  'confidence': 907,
#  'brokerages': 908,
#  'expand': 909,
#  'phone': 910,
#  'r': 911,
#  'grows': 912,
#  'hope': 913,
#  'land': 914,
#  'america': 915,
#  'worry': 916,
#  'diwali': 917,
#  'solar': 918,
#  'रुपये': 919,
#  'lok': 920,
#  'cos': 921,
#  'card': 922,
#  'ecb': 923,
#  'farmer': 924,
#  'targets': 925,
#  'estimates': 926,
#  'operations': 927,
#  'hul': 928,
#  'general': 929,
#  'joe': 930,
#  'nbfc': 931,
#  'row': 932,
#  'fine': 933,
#  'direct': 934,
#  'segment': 935,
#  'lic': 936,
#  'sip': 937,
#  'yuan': 938,
#  'class': 939,
#  'सोने': 940,
#  'raghuram': 941,
#  'poor': 942,
#  'if': 943,
#  'galaxy': 944,
#  'vehicles': 945,
#  'middle': 946,
#  'x': 947,
#  'bigger': 948,
#  'property': 949,
#  'who': 950,
#  'pro': 951,
#  'planning': 952,
#  'single': 953,
#  'buffett': 954,
#  'starts': 955,
#  'kerala': 956,
#  'commodities': 957,
#  'decade': 958,
#  'commercial': 959,
#  'important': 960,
#  'crucial': 961,
#  'hyundai': 962,
#  'slows': 963,
#  'निफ्टी': 964,
#  'wave': 965,
#  'black': 966,
#  'east': 967,
#  'shankar': 968,
#  'globally': 969,
#  'sinha': 970,
#  'politics': 971,
#  'vedanta': 972,
#  'plunges': 973,
#  'goes': 974,
#  'buyers': 975,
#  'mfs': 976,
#  'rich': 977,
#  'il': 978,
#  'files': 979,
#  'plunge': 980,
#  'goldman': 981,
#  'uncertainty': 982,
#  'benefits': 983,
#  'driving': 984,
#  'creation': 985,
#  'law': 986,
#  'save': 987,
#  'lows': 988,
#  'stanley': 989,
#  'parliament': 990,
#  'oyo': 991,
#  'leader': 992,
#  'fastest': 993,
#  'vote': 994,
#  'minutes': 995,
#  'outbreak': 996,
#  'cabinet': 997,
#  'softbank': 998,
#  'partners': 999,
#  'make': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 27782

# %% [markdown]
# # Glove Embeddings

# %%
embeddings_index= dict()
glove= open('glove.6B.100d.txt','r',encoding='utf-8') 
for line in glove:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs

glove.close()

# %%
len(embeddings_index)
# Out:
# 400000

# %%
### Create an embedding matrix for the vocabulary   
vocab= len(tokenizer.word_index)+1   #determines the length of the vocabulary by adding one to the maximum index of the tokenizer's word index
embedding_matrix = np.zeros((vocab, 100)) #initializes an embedding matrix where vocab is the length of the vocabulary and 100 is the dimensionality of the pre-trained word embeddings 
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector 
        #iterates over each word in the tokenizer's word index and retrieves the pre-trained embedding vector 
        #for that word from a pre-trained embedding index (GloVe). If the embedding vector is found, it is assigned to the corresponding row in the 
        #embedding matrix (i.e., the ith row, where i is the index of the word in the tokenizer's word index). 
        #If the embedding vector is not found, the corresponding row in the embedding matrix is left as a row of zeros.

# %%
embedding_matrix.shape
# Out:
# (27783, 100)

# %%
train_indices=tokenizer.texts_to_sequences(train_text) #using a tokenizer to convert a list of text strings into a list of sequences of integers.

# %%
train_indices[0:3]
# Out:
# [[4501, 1394, 979, 4, 25, 77],
#  [299, 126, 6877, 26, 3678, 192, 1049, 3959, 3960],
#  [705, 706, 630, 390, 61, 16, 150, 359, 6359, 152, 20, 3679, 9, 289]]

# %% [markdown]
# # Pad Sequences

# %% [markdown]
# max_length=64
# The pad_sequences() function takes a list of sequences (in this case, train_indices) as input and pads or truncates the sequences to a fixed length. In this case, the maxlen parameter is set to 64, which means that all sequences will be padded or truncated to a length of 64.
#
# If a sequence is shorter than 64 elements, it will be padded with zeros at the end (since padding='post'). If a sequence is longer than 64 elements, it will be truncated to the first 64 elements.
#
# After the padding is applied, the resulting sequences are stored back into the train_indices variable.
#
# The reason for doing this padding is that neural networks usually require inputs to have a fixed size. In this case, all input sequences are of the same length (64), which makes it possible to use them as input to a neural network model.
#
# Without the padding, the sequences might have different lengths, which would make it difficult to use them as input features for a neural network.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_length=64
train_indices=pad_sequences(train_indices,maxlen=max_length,padding='post')

# %%
df['sentiment'].value_counts()
# Out:
# NEGATIVE    29988
# POSITIVE    29985
# Name: sentiment, dtype: int64

# %%
#replace() method is used to replace the string values "POSITIVE" and "NEGATIVE" in the sentiment column with the integer 
#values 1 and 0, respectively. 
df['sentiment'].replace(['POSITIVE','NEGATIVE'],[1,0],inplace=True)
df['sentiment'].value_counts() 
#value_counts() method is used to count the number of occurrences of each unique value in the sentiment column.
# Out:
# 0    29988
# 1    29985
# Name: sentiment, dtype: int64

# %%
Y=list(df['sentiment'])
train_y=Y[:len(Y)-500]
test_y=Y[-500:]
print(len(train_y),len(test_y))
# Out:
# 59473 500

# %%
train_indices=np.asarray(train_indices)
train_y=np.asarray(train_y)

# %%
test_indices=tokenizer.texts_to_sequences(test_text)
test_indices=pad_sequences(test_indices,maxlen=max_length,padding='post')
test_indices=np.asarray(test_indices)
test_y=np.asarray(test_y)

# %% [markdown]
# # Simple RNN with dropouts

# %% [markdown]
# Sequential() is a class in the Keras API for building a sequential model in deep learning. The model is a linear stack of layers where each layer is connected to the next layer, forming a sequence of layers.
#
# The Sequential() function initializes an empty sequential model object that can be used to add layers one after the other. Once we have created the model using Sequential(), we can add layers to the model using the add() method.

# %%
# defining a sequential neural network model using the Keras API
vocab= len(tokenizer.word_index)+1 #calculates the vocabulary size of the input data 
modelRNN= Sequential()
modelRNN.add(Embedding(input_dim=vocab,output_dim=100,input_length=max_length)) #input sequences of integers as input and converts them into dense vectors of fixed size
modelRNN.add(Dropout(0.3))# dropping at input level to prevent overfitting
modelRNN.add(SimpleRNN(32))#SimpleRNN layer has 32 units, which determines the dimensionality of the internal state.
modelRNN.add(Dropout(0.3))# another drop out layer added after RNN to prevent overfitting
modelRNN.add(Dense(1, activation='sigmoid'))#fully connected layer that produces a single output value between 0 and 1 with use of sigmoid function
modelRNN.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#compile() method is used to compile the model, specifying the loss function ('binary_crossentropy'), the optimizer ('adam'),
# and the evaluation metric ('accuracy').

print(modelRNN.summary())# print a summary of the model architecture
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 64, 100)           2778300
#
#  dropout_2 (Dropout)         (None, 64, 100)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                4256
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,782,589
# Trainable params: 2,782,589
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# *train_indices is the input data for the model, typically a set of training examples that have been converted into numerical features.
#
# *train_y is the output data for the model, which typically consists of labels or target values that the model is trying to predict.
#
# *epochs specifies the number of times the model will iterate over the entire training dataset during training. Each iteration over the dataset is called an epoch.
#
# *batch_size specifies the number of training examples that the model will use at once to update its parameters during each epoch. The model will use mini-batch stochastic gradient descent to optimize the parameters.
#
# *validation_split specifies the proportion of the training data that will be used for validation during training. In this case, 20% of the training data will be used for validation, and the remaining 80% will be used for actual training.

# %%
# Train the model
history = modelRNN.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = modelRNN.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelRNN.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]
#threshold for classifying an example as positive or negative is set to 0.5. Any predicted output 
#value above 0.5 is classified as a positive example, and any predicted output value below or equal to 0.5 
#is classified as a negative example. 

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelRNN.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy:', train_acc)
print('Test Accuracy:', test_acc)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
print('AUC Score:', auc_score)

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
# Out:
# Epoch 1/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.6391 - accuracy: 0.6436 - val_loss: 0.6070 - val_accuracy: 0.6874
# Epoch 2/10
# 1487/1487 [==============================] - 26s 18ms/step - loss: 0.5485 - accuracy: 0.7428 - val_loss: 0.5672 - val_accuracy: 0.7212
# Epoch 3/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.4940 - accuracy: 0.7808 - val_loss: 0.5567 - val_accuracy: 0.7312
# Epoch 4/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.4567 - accuracy: 0.8050 - val_loss: 0.5560 - val_accuracy: 0.7382
# Epoch 5/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.4366 - accuracy: 0.8178 - val_loss: 0.5681 - val_accuracy: 0.7380
# Epoch 6/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.4198 - accuracy: 0.8300 - val_loss: 0.5907 - val_accuracy: 0.7217
# Epoch 7/10
# 1487/1487 [==============================] - 26s 17ms/step - loss: 0.4169 - accuracy: 0.8285 - val_loss: 0.5796 - val_accuracy: 0.7282
# Epoch 8/10
# 1487/1487 [==============================] - 25s 17ms/step - loss: 0.3940 - accuracy: 0.8424 - val_loss: 0.5981 - val_accuracy: 0.7168
# Epoch 9/10
# 1487/1487 [==============================] - 25s 17ms/step - loss: 0.3793 - accuracy: 0.8502 - val_loss: 0.5976 - val_accuracy: 0.7314
# Epoch 10/10
# 1487/1487 [==============================] - 25s 17ms/step - loss: 0.3726 - accuracy: 0.8519 - val_loss: 0.6161 - val_accuracy: 0.7132
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6382 - accuracy: 0.7000
# 16/16 [==============================] - 0s 2ms/step
# 1859/1859 [==============================] - 3s 1ms/step
# Train Accuracy: 0.8438451061826375
# Test Accuracy: 0.7
# Precision: 0.6865671641791045
# Recall: 0.736
# F1 Score: 0.7104247104247104
# AUC Score: 0.764352

# %% [markdown]
# # LSTM with dropouts

# %%
## Creating the model architecture-- Dropouts with LSTM
vocab= len(tokenizer.word_index)+1 #calculates the vocabulary size of the input data 
modelLSTM= Sequential()
modelLSTM.add(Embedding(input_dim=vocab,output_dim=100,input_length=max_length))#input sequences of integers as input and converts them into dense vectors of fixed size
modelLSTM.add(Dropout(0.3))# dropping at input level to prevent overfitting
modelLSTM.add(LSTM(32))#adds a Long Short-Term Memory (LSTM) layer to the model.'32' specifies the number of output units in the LSTM layer
modelLSTM.add(Dropout(0.3))#adds another dropout layer after the LSTM layer to further prevent overfitting
modelLSTM.add(Dense(1, activation='sigmoid'))#fully connected layer that produces a single output value between 0 and 1 with use of sigmoid function
modelLSTM.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#compile() method is used to compile the model, specifying the loss function ('binary_crossentropy'), the optimizer ('adam'),
# and the evaluation metric ('accuracy').
print(modelLSTM.summary())# print a summary of the model architecture
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 64, 100)           2778300
#
#  dropout_4 (Dropout)         (None, 64, 100)           0
#
#  lstm (LSTM)                 (None, 32)                17024
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,795,357
# Trainable params: 2,795,357
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
history = modelLSTM.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = modelLSTM.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelLSTM.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]
#threshold for classifying an example as positive or negative is set to 0.5. Any predicted output 
#value above 0.5 is classified as a positive example, and any predicted output value below or equal to 0.5 
#is classified as a negative example. 

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelLSTM.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy of LSTM model:', train_acc)
print('Test Accuracy of LSTM model:', test_acc)
print('Precision of LSTM model:', precision)
print('Recall of LSTM model:', recall)
print('F1 Score of LSTM model:', f1)
print('AUC Score:', auc_score)

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
# Out:
# Epoch 1/10
# 1487/1487 [==============================] - 33s 21ms/step - loss: 0.6936 - accuracy: 0.4938 - val_loss: 0.6930 - val_accuracy: 0.5083
# Epoch 2/10
# 1487/1487 [==============================] - 31s 21ms/step - loss: 0.6934 - accuracy: 0.5011 - val_loss: 0.6932 - val_accuracy: 0.4917
# Epoch 3/10
# 1487/1487 [==============================] - 32s 21ms/step - loss: 0.6933 - accuracy: 0.4971 - val_loss: 0.6931 - val_accuracy: 0.5083
# Epoch 4/10
# 1487/1487 [==============================] - 32s 21ms/step - loss: 0.6933 - accuracy: 0.4979 - val_loss: 0.6933 - val_accuracy: 0.4917
# Epoch 5/10
# 1487/1487 [==============================] - 32s 21ms/step - loss: 0.6933 - accuracy: 0.4972 - val_loss: 0.6930 - val_accuracy: 0.5083
# Epoch 6/10
# 1487/1487 [==============================] - 32s 21ms/step - loss: 0.6933 - accuracy: 0.5027 - val_loss: 0.6930 - val_accuracy: 0.5083
# Epoch 7/10
# 1487/1487 [==============================] - 32s 21ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4917
# Epoch 8/10
# 1487/1487 [==============================] - 33s 22ms/step - loss: 0.6932 - accuracy: 0.5047 - val_loss: 0.6931 - val_accuracy: 0.5083
# Epoch 9/10
# 1487/1487 [==============================] - 32s 22ms/step - loss: 0.6933 - accuracy: 0.4997 - val_loss: 0.6933 - val_accuracy: 0.4917
# Epoch 10/10
# 1487/1487 [==============================] - 33s 22ms/step - loss: 0.6933 - accuracy: 0.4962 - val_loss: 0.6936 - val_accuracy: 0.4917
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.5000
# 16/16 [==============================] - 0s 3ms/step
# 1859/1859 [==============================] - 6s 3ms/step
# Train Accuracy of LSTM model: 0.49997477847090277
# Test Accuracy of LSTM model: 0.5
# Precision of LSTM model: 0.5
# Recall of LSTM model: 1.0
# F1 Score of LSTM model: 0.6666666666666666
# AUC Score: 0.5

# %% [markdown]
# #  Bidirectional Model

# %%
## Layer normalization is another regularization technique used to prevent overfitting by normalizing 
## the activations of the neurons in the layer

### Strengthening using bidirectional SimpleRNN

vocab= len(tokenizer.word_index)+1#calculates the vocabulary size of the input data 
modelbidr= Sequential()
modelbidr.add(Embedding(input_dim=vocab,output_dim=100,input_length=max_length))#input sequences of integers as input and converts them into dense vectors of fixed size
modelbidr.add(Dropout(0.3))# dropping at input level to prevent overfitting
modelbidr.add(Bidirectional(SimpleRNN(32)))#adds a Bidirectional SimpleRNN layer to the model.
modelbidr.add(LayerNormalization()) #dds a LayerNormalization layer to the model
modelbidr.add(Dropout(0.3))#adds another dropout layer after the layer Normalisation layer to further prevent overfitting
modelbidr.add(Dense(1, activation='sigmoid'))#fully connected layer that produces a single output value between 0 and 1 with use of sigmoid function
modelbidr.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(modelbidr.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 64, 100)           2778300
#
#  dropout_6 (Dropout)         (None, 64, 100)           0
#
#  bidirectional (Bidirectiona  (None, 64)               8512
#  l)
#
#  layer_normalization (LayerN  (None, 64)               128
#  ormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,787,005
# Trainable params: 2,787,005
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
history = modelbidr.fit(train_indices, train_y, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = modelbidr.evaluate(test_indices, test_y)

# Make predictions
test_pred = modelbidr.predict(test_indices)
test_pred_classes = [1 if p > 0.5 else 0 for p in test_pred]
#threshold for classifying an example as positive or negative is set to 0.5. Any predicted output 
#value above 0.5 is classified as a positive example, and any predicted output value below or equal to 0.5 
#is classified as a negative example. 

# Calculate accuracy, precision, recall, and F1 score
train_pred = modelbidr.predict(train_indices)
train_pred_classes = [1 if p > 0.5 else 0 for p in train_pred]

train_acc = accuracy_score(train_y, train_pred_classes)
test_acc = accuracy_score(test_y, test_pred_classes)

precision = precision_score(test_y, test_pred_classes)
recall = recall_score(test_y, test_pred_classes)
f1 = f1_score(test_y, test_pred_classes)

# Calculate AUC
fpr, tpr, thresholds = roc_curve(test_y, test_pred)
auc_score = auc(fpr, tpr)

# Print the results
print('Train Accuracy of Bidirectional RNN model:', train_acc)
print('Test Accuracy of Bidirectional RNN model:', test_acc)
print('Precision of Bidirectional RNN model:', precision)
print('Recall of Bidirectional RNN model:', recall)
print('F1 Score of Bidirectional RNN model:', f1)
print('AUC Score:', auc_score)

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
# Out:
# Epoch 1/10
# 1487/1487 [==============================] - 31s 20ms/step - loss: 0.5830 - accuracy: 0.6869 - val_loss: 0.5011 - val_accuracy: 0.7546
# Epoch 2/10
# 1487/1487 [==============================] - 29s 20ms/step - loss: 0.4173 - accuracy: 0.8103 - val_loss: 0.5111 - val_accuracy: 0.7544
# Epoch 3/10
# 1487/1487 [==============================] - 29s 20ms/step - loss: 0.3053 - accuracy: 0.8715 - val_loss: 0.5761 - val_accuracy: 0.7446
# Epoch 4/10
# 1487/1487 [==============================] - 29s 20ms/step - loss: 0.2217 - accuracy: 0.9121 - val_loss: 0.6572 - val_accuracy: 0.7331
# Epoch 5/10
# 1487/1487 [==============================] - 29s 20ms/step - loss: 0.1774 - accuracy: 0.9319 - val_loss: 0.7297 - val_accuracy: 0.7289
# Epoch 6/10
# 1487/1487 [==============================] - 29s 20ms/step - loss: 0.1456 - accuracy: 0.9447 - val_loss: 0.8326 - val_accuracy: 0.7243
# Epoch 7/10
# 1487/1487 [==============================] - 32s 22ms/step - loss: 0.1277 - accuracy: 0.9522 - val_loss: 0.8698 - val_accuracy: 0.7222
# Epoch 8/10
# 1487/1487 [==============================] - 32s 22ms/step - loss: 0.1142 - accuracy: 0.9565 - val_loss: 0.9588 - val_accuracy: 0.7032
# Epoch 9/10
# 1487/1487 [==============================] - 32s 22ms/step - loss: 0.1048 - accuracy: 0.9613 - val_loss: 1.0487 - val_accuracy: 0.7064
# Epoch 10/10
# 1487/1487 [==============================] - 32s 22ms/step - loss: 0.0925 - accuracy: 0.9657 - val_loss: 1.0957 - val_accuracy: 0.6955
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1674 - accuracy: 0.6980
# 16/16 [==============================] - 0s 4ms/step
# 1859/1859 [==============================] - 5s 3ms/step
# Train Accuracy of Bidirectional RNN model: 0.9293124611168093
# Test Accuracy of Bidirectional RNN model: 0.698
# Precision of Bidirectional RNN model: 0.6987951807228916
# Recall of Bidirectional RNN model: 0.696
# F1 Score of Bidirectional RNN model: 0.6973947895791583
# AUC Score: 0.7512
